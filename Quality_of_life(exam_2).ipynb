# %% [markdown]
# <a href="https://colab.research.google.com/github/vvega7/Chanel7/blob/main/Quality_of_life(exam_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Intro**
#
# Database shows the quality of life indices worldwide in the years 2020 and 2018.

# %%
# Libraries

import numpy as np
import pandas as pd

# %% [markdown]
# #**2. Import**

# %%
# Save the path o the file
p = '/calidad.xlsx'

# Read the file
d = pd.read_excel(p)

#check
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            147 non-null    int64
#  1   Rank                            147 non-null    int64
#  2   Country                         147 non-null    object
#  3   Quality of Life Index           147 non-null    float64
#  4   Purchasing Power Index          147 non-null    float64
#  5   Safety Index                    147 non-null    float64
#  6   Health Care Index               147 non-null    float64
#  7   Cost of Living Index            147 non-null    float64
#  8   Property Price to Income Ratio  147 non-null    float64
#  9   Traffic Commute Time Index      147 non-null    float64
#  10  Pollution Index                 147 non-null    float64
#  11  Climate Index                   147 non-null    float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 13.9+ KB

# %%
# Check the first entries
d.head()
# Out:
#    Year  Rank      Country  Quality of Life Index  Purchasing Power Index  \
# 0  2018     1      Denmark                  197.7                   117.5
# 1  2018     2      Finland                  195.3                   119.4
# 2  2018     3  Netherlands                  191.3                   109.5
# 3  2018     4  Switzerland                  190.8                   126.1
# 4  2018     5      Austria                  190.2                    98.7
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0          78.0               77.1                  93.3
# 1          76.3               75.4                  81.7
# 2          71.1               81.1                  82.7
# 3          78.2               71.7                 131.4
# 4          79.6               78.8                  81.5
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                             7.2                        28.5
# 1                             7.5                        33.2
# 2                             6.7                        32.7
# 3                            10.9                        29.3
# 4                             9.6                        27.0
#
#    Pollution Index  Climate Index
# 0             23.6           82.4
# 1             12.1           58.6
# 2             27.2           86.9
# 3             23.0           79.8
# 4             22.9           77.7

# %%
# Check the last entries
d.tail()
# Out:
#      Year  Rank     Country  Quality of Life Index  Purchasing Power Index  \
# 142  2022    83   Venezuela                   77.4                    15.4
# 143  2022    84   Sri Lanka                   67.9                    19.3
# 144  2022    85  Bangladesh                   67.6                    25.3
# 145  2022    86        Iran                   64.9                    18.0
# 146  2022    87     Nigeria                   52.4                     9.3
#
#      Safety Index  Health Care Index  Cost of Living Index  Property Price  \
# 142          16.4               39.3                  43.2            14.4
# 143          58.8               72.1                  31.3            46.0
# 144          36.6               42.3                  33.1            13.5
# 145          50.9               52.3                  37.4            33.0
# 146          36.2               48.5                  30.5            16.1
#
#      Traffic time  Pollution Index  Climate Index Year_str
# 142          34.1             75.4           99.9     2022
# 143          57.1             60.2           59.1     2022
# 144          55.9             85.0           71.3     2022
# 145          47.1             75.4           65.7     2022
# 146          62.0             88.3           60.8     2022

# %% [markdown]
# # **3. Cleaning**

# %% [markdown]
# ## Column Names

# %%
# Change Time for year
d.rename(columns = {"Property Price to Income Ratio":"Property Price"}, inplace= True)


d.rename(columns = {"Traffic Commute Time Index":"Traffic time"}, inplace= True)

# %% [markdown]
# ## Delete Columns

# %%
p = d.drop(columns = ['Purchasing Power Index','Health Care Index'])
p.head()
# Out:
#    Year  Rank      Country  Quality of Life Index  Safety Index  \
# 0  2018     1      Denmark                  197.7          78.0
# 1  2018     2      Finland                  195.3          76.3
# 2  2018     3  Netherlands                  191.3          71.1
# 3  2018     4  Switzerland                  190.8          78.2
# 4  2018     5      Austria                  190.2          79.6
#
#    Cost of Living Index  Property Price  Traffic time  Pollution Index  \
# 0                  93.3             7.2          28.5             23.6
# 1                  81.7             7.5          33.2             12.1
# 2                  82.7             6.7          32.7             27.2
# 3                 131.4            10.9          29.3             23.0
# 4                  81.5             9.6          27.0             22.9
#
#    Climate Index Year_str
# 0           82.4     2018
# 1           58.6     2018
# 2           86.9     2018
# 3           79.8     2018
# 4           77.7     2018

# %% [markdown]
# #**A few more thing**

# %%
# (optional) Duplicate the dataframe
pp = d

# %%
# Duplicate year variable
pp["Year_str"] = pp["Year"].astype(str)

# check
pp.head()
# Out:
#    Year  Rank      Country  Quality of Life Index  Purchasing Power Index  \
# 0  2018     1      Denmark                  197.7                   117.5
# 1  2018     2      Finland                  195.3                   119.4
# 2  2018     3  Netherlands                  191.3                   109.5
# 3  2018     4  Switzerland                  190.8                   126.1
# 4  2018     5      Austria                  190.2                    98.7
#
#    Safety Index  Health Care Index  Cost of Living Index  Property Price  \
# 0          78.0               77.1                  93.3             7.2
# 1          76.3               75.4                  81.7             7.5
# 2          71.1               81.1                  82.7             6.7
# 3          78.2               71.7                 131.4            10.9
# 4          79.6               78.8                  81.5             9.6
#
#    Traffic time  Pollution Index  Climate Index Year_str
# 0          28.5             23.6           82.4     2018
# 1          33.2             12.1           58.6     2018
# 2          32.7             27.2           86.9     2018
# 3          29.3             23.0           79.8     2018
# 4          27.0             22.9           77.7     2018
